# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("22IT085_Pre-processed_Dataset.csv")  # Replace with your CSV file name
train_df = df.sample(frac=0.8, random_state=42)  # 80% of the data
test_df = df.drop(train_df.index)  # Remaining 20% of the data

# Save the two parts as separate CSV files
train_df.to_csv("train.csv", index=False)
test_df.to_csv("test.csv", index=False)

print("CSV files saved: train.csv (80%), test.csv (20%)")
# Out:
# CSV files saved: train.csv (80%), test.csv (20%)

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

# -----------------------
# Define a custom reconstruction accuracy metric.
# This metric thresholds the true and predicted values at 0.5 and
# calculates the proportion of features that exactly match.
# -----------------------
def reconstruction_accuracy(y_true, y_pred):
    y_true_bin = tf.cast(y_true > 0.5, tf.float32)
    y_pred_bin = tf.cast(y_pred > 0.5, tf.float32)
    equal = tf.equal(y_true_bin, y_pred_bin)
    return tf.reduce_mean(tf.cast(equal, tf.float32))

# -----------------------
# Define a custom callback to measure epoch time.
# -----------------------
class TimeHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self.times = []
        self.cumulative_times = []
    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_time_start = time.time()
    def on_epoch_end(self, epoch, logs=None):
        epoch_time = time.time() - self.epoch_time_start
        self.times.append(epoch_time)
        # Calculate cumulative time
        if self.cumulative_times:
            cum_time = self.cumulative_times[-1] + epoch_time
        else:
            cum_time = epoch_time
        self.cumulative_times.append(cum_time)

# -----------------------
# Load training data from train.csv
# -----------------------
# Assume train.csv has 97 features, with the last column as target.
df_train = pd.read_csv("train.csv").iloc[:10000, :]
target_col = df_train.columns[-1]
features = df_train.drop(columns=target_col)
target = df_train[target_col]

# (Optional) Remove highly correlated features if needed
corr_matrix = features.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
threshold = 0.9
to_drop = [col for col in upper.columns if any(upper[col] > threshold)]
features_final = features.drop(columns=to_drop)
print("Removed highly correlated columns:", to_drop)

# Save cleaned dataset if needed
df_clean = features_final.copy()
df_clean.to_csv("cleaned_dataset.csv", index=False)
print("Cleaned dataset shape:", df_clean.shape)

# Convert features to numpy array and scale them between 0 and 1
X = df_clean.values
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# -----------------------
# Define the autoencoder model
# -----------------------
input_dim = X_scaled.shape[1]
encoding_dim = 15

input_layer = Input(shape=(input_dim,))
encoder = Dense(encoding_dim, activation='relu')(input_layer)
decoder = Dense(input_dim, activation='sigmoid')(encoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)
# We add two metrics: MAE and our custom reconstruction accuracy.
autoencoder.compile(optimizer='adam', loss='mse', metrics=['mae', reconstruction_accuracy])
autoencoder.summary()

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Instantiate our time recording callback
time_history = TimeHistory()

# -----------------------
# Train the model and measure training time
# -----------------------
start_time = time.time()
history = autoencoder.fit(X_scaled, X_scaled,
                          epochs=500,
                          batch_size=16,
                          shuffle=True,
                          validation_split=0.2,
                          callbacks=[early_stopping, time_history],
                          verbose=1)
total_training_time = time.time() - start_time
print(f"Total training time: {total_training_time:.2f} seconds")

# Save overall training time to an Excel file
df_total_time = pd.DataFrame({"TotalTrainingTimeSeconds": [total_training_time]})
df_total_time.to_excel("studentname-regnumber-trainingtime.xlsx", index=False)

# -----------------------
# Save training metrics (excluding time metrics) per epoch to an Excel file.
# -----------------------
epochs = range(1, len(history.history['loss']) + 1)
df_metrics = pd.DataFrame({
    "Epoch": epochs,
    "TrainingLoss": history.history['loss'],
    "ValidationLoss": history.history['val_loss'],
    "TrainingMAE": history.history['mae'],
    "ValidationMAE": history.history['val_mae'],
    "TrainingAccuracy": history.history['reconstruction_accuracy'],
    "ValidationAccuracy": history.history['val_reconstruction_accuracy']
})
print(df_metrics)

# Write training metrics into one Excel file with two sheets.
with pd.ExcelWriter("studentname-regnumber-trainingmetrics.xlsx") as writer:
    df_metrics.to_excel(writer, sheet_name="All_Metrics", index=False)
    df_accuracy = pd.DataFrame({
         "Epoch": epochs,
         "TrainingAccuracy": history.history['reconstruction_accuracy'],
         "ValidationAccuracy": history.history['val_reconstruction_accuracy']
    })
    df_accuracy.to_excel(writer, sheet_name="Accuracy", index=False)

# -----------------------
# Save time-related metrics (epoch time and cumulative time) to a different Excel file.
# -----------------------
df_time = pd.DataFrame({
    "Epoch": epochs,
    "EpochTimeSeconds": time_history.times,
    "CumulativeTimeSeconds": time_history.cumulative_times
})
df_time.to_excel("studentname-regnumber-epochtime.xlsx", index=False)

# -----------------------
# Plot metrics vs. epochs and save the graphs
# -----------------------

# Plot reconstruction accuracy vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['reconstruction_accuracy'], label="Training Accuracy")
plt.plot(epochs, history.history['val_reconstruction_accuracy'], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Reconstruction Accuracy")
plt.title("Training and Validation Accuracy vs Epochs")
plt.legend()
plt.savefig("studentname-regnumber-accuracygraph.jpeg")
plt.show()

# Plot loss vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['loss'], label="Training Loss")
plt.plot(epochs, history.history['val_loss'], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training and Validation Loss vs Epochs")
plt.legend()
plt.savefig("studentname-regnumberlossgraph.jpeg")
plt.show()

# Plot MAE vs epochs
plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['mae'], label="Training MAE")
plt.plot(epochs, history.history['val_mae'], label="Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("Mean Absolute Error")
plt.title("Training and Validation MAE vs Epochs")
plt.legend()
plt.savefig("studentname-regnumber-maegraph.jpeg")
plt.show()

# -----------------------
# Print output plots for each layer (encoder and decoder)
# -----------------------
# Create the encoder model
encoder_model = Model(inputs=input_layer, outputs=encoder)
# Get the encoder (compressed) output
encoder_output = encoder_model.predict(X_scaled)
# Get the decoder (reconstructed) output from the full autoencoder
decoder_output = autoencoder.predict(X_scaled)

# Plot the distribution of encoder outputs
plt.figure(figsize=(10, 6))
plt.hist(encoder_output.flatten(), bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Encoder Layer Output")
plt.xlabel("Activation Value")
plt.ylabel("Frequency")
plt.savefig("studentname-regnumber-encoderoutput.jpeg")
plt.show()

# Plot the distribution of decoder outputs
plt.figure(figsize=(10, 6))
plt.hist(decoder_output.flatten(), bins=30, color='salmon', edgecolor='black')
plt.title("Distribution of Decoder Layer Output")
plt.xlabel("Activation Value")
plt.ylabel("Frequency")
plt.savefig("studentname-regnumber-decoderoutput.jpeg")
plt.show()

# -----------------------
# Save the encoder model separately
# -----------------------
encoder_model.save("encoder_model.h5")
print("Encoder model saved as 'encoder_model.h5'")
# Out:
# Removed highly correlated columns: ['char_repeat_hostname', 'char_repeat_path', 'shortest_word_hostname', 'longest_word_hostname', 'average_word_length_hostname', 'email_in_url', 'vowel_count_in_domain', 'domain_lookup_response_time', 'nameservers_count', 'number_of_parameters', 'dns_record_check']
# Cleaned dataset shape: (10000, 104)
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 104)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 15)             │         1,575 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 104)            │         1,664 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,239 (12.65 KB)
#  Trainable params: 3,239 (12.65 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - loss: 0.0971 - mae: 0.2476 - reconstruction_accuracy: 0.8879 - val_loss: 0.0116 - val_mae: 0.0500 - val_reconstruction_accuracy: 0.9841
# Epoch 2/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0102 - mae: 0.0454 - reconstruction_accuracy: 0.9850 - val_loss: 0.0082 - val_mae: 0.0390 - val_reconstruction_accuracy: 0.9869
# Epoch 3/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.0072 - mae: 0.0369 - reconstruction_accuracy: 0.9880 - val_loss: 0.0058 - val_mae: 0.0323 - val_reconstruction_accuracy: 0.9897
# Epoch 4/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.0052 - mae: 0.0307 - reconstruction_accuracy: 0.9902 - val_loss: 0.0046 - val_mae: 0.0282 - val_reconstruction_accuracy: 0.9906
# Epoch 5/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0042 - mae: 0.0271 - reconstruction_accuracy: 0.9909 - val_loss: 0.0039 - val_mae: 0.0252 - val_reconstruction_accuracy: 0.9912
# Epoch 6/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0037 - mae: 0.0247 - reconstruction_accuracy: 0.9911 - val_loss: 0.0034 - val_mae: 0.0235 - val_reconstruction_accuracy: 0.9912
# Epoch 7/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.0032 - mae: 0.0228 - reconstruction_accuracy: 0.9912 - val_loss: 0.0028 - val_mae: 0.0215 - val_reconstruction_accuracy: 0.9920
# Epoch 8/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0027 - mae: 0.0209 - reconstruction_accuracy: 0.9920 - val_loss: 0.0024 - val_mae: 0.0194 - val_reconstruction_accuracy: 0.9922
# Epoch 9/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.0023 - mae: 0.0190 - reconstruction_accuracy: 0.9922 - val_loss: 0.0021 - val_mae: 0.0179 - val_reconstruction_accuracy: 0.9924
# Epoch 10/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.0020 - mae: 0.0173 - reconstruction_accuracy: 0.9924 - val_loss: 0.0019 - val_mae: 0.0167 - val_reconstruction_accuracy: 0.9925
# Epoch 11/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 0.0018 - mae: 0.0164 - reconstruction_accuracy: 0.9927 - val_loss: 0.0017 - val_mae: 0.0157 - val_reconstruction_accuracy: 0.9927
# Epoch 12/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 0.0017 - mae: 0.0153 - reconstruction_accuracy: 0.9928 - val_loss: 0.0016 - val_mae: 0.0149 - val_reconstruction_accuracy: 0.9930
# Epoch 13/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.0015 - mae: 0.0145 - reconstruction_accuracy: 0.9930 - val_loss: 0.0014 - val_mae: 0.0141 - val_reconstruction_accuracy: 0.9934
# Epoch 14/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.0014 - mae: 0.0138 - reconstruction_accuracy: 0.9934 - val_loss: 0.0013 - val_mae: 0.0133 - val_reconstruction_accuracy: 0.9936
# Epoch 15/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0012 - mae: 0.0130 - reconstruction_accuracy: 0.9939 - val_loss: 0.0012 - val_mae: 0.0128 - val_reconstruction_accuracy: 0.9943
# Epoch 16/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 0.0011 - mae: 0.0125 - reconstruction_accuracy: 0.9944 - val_loss: 0.0011 - val_mae: 0.0122 - val_reconstruction_accuracy: 0.9946
# Epoch 17/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 9.8894e-04 - mae: 0.0119 - reconstruction_accuracy: 0.9949 - val_loss: 9.7196e-04 - val_mae: 0.0116 - val_reconstruction_accuracy: 0.9949
# Epoch 18/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - loss: 9.3670e-04 - mae: 0.0115 - reconstruction_accuracy: 0.9956 - val_loss: 9.1346e-04 - val_mae: 0.0113 - val_reconstruction_accuracy: 0.9956
# Epoch 19/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - loss: 8.5867e-04 - mae: 0.0111 - reconstruction_accuracy: 0.9959 - val_loss: 8.7481e-04 - val_mae: 0.0110 - val_reconstruction_accuracy: 0.9956
# Epoch 20/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 8.0808e-04 - mae: 0.0108 - reconstruction_accuracy: 0.9963 - val_loss: 8.3606e-04 - val_mae: 0.0107 - val_reconstruction_accuracy: 0.9960
# Epoch 21/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 8.0743e-04 - mae: 0.0106 - reconstruction_accuracy: 0.9965 - val_loss: 8.0934e-04 - val_mae: 0.0104 - val_reconstruction_accuracy: 0.9961
# Epoch 22/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 7.4909e-04 - mae: 0.0103 - reconstruction_accuracy: 0.9968 - val_loss: 7.8581e-04 - val_mae: 0.0103 - val_reconstruction_accuracy: 0.9967
# Epoch 23/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 7.2572e-04 - mae: 0.0101 - reconstruction_accuracy: 0.9969 - val_loss: 7.8001e-04 - val_mae: 0.0101 - val_reconstruction_accuracy: 0.9970
# Epoch 24/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 7.0371e-04 - mae: 0.0099 - reconstruction_accuracy: 0.9971 - val_loss: 7.5948e-04 - val_mae: 0.0099 - val_reconstruction_accuracy: 0.9969
# Epoch 25/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 7.2503e-04 - mae: 0.0099 - reconstruction_accuracy: 0.9970 - val_loss: 7.5192e-04 - val_mae: 0.0099 - val_reconstruction_accuracy: 0.9971
# Epoch 26/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 7.1885e-04 - mae: 0.0098 - reconstruction_accuracy: 0.9971 - val_loss: 7.3717e-04 - val_mae: 0.0097 - val_reconstruction_accuracy: 0.9970
# Epoch 27/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 6.8122e-04 - mae: 0.0096 - reconstruction_accuracy: 0.9972 - val_loss: 7.2913e-04 - val_mae: 0.0097 - val_reconstruction_accuracy: 0.9972
# Epoch 28/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 6.7883e-04 - mae: 0.0095 - reconstruction_accuracy: 0.9973 - val_loss: 7.1572e-04 - val_mae: 0.0096 - val_reconstruction_accuracy: 0.9967
# Epoch 29/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 6.6498e-04 - mae: 0.0095 - reconstruction_accuracy: 0.9974 - val_loss: 7.0934e-04 - val_mae: 0.0096 - val_reconstruction_accuracy: 0.9970
# Epoch 30/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 6.4211e-04 - mae: 0.0094 - reconstruction_accuracy: 0.9976 - val_loss: 7.0209e-04 - val_mae: 0.0095 - val_reconstruction_accuracy: 0.9974
# Epoch 31/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 6.2898e-04 - mae: 0.0093 - reconstruction_accuracy: 0.9976 - val_loss: 6.9170e-04 - val_mae: 0.0094 - val_reconstruction_accuracy: 0.9973
# Epoch 32/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 6.1781e-04 - mae: 0.0093 - reconstruction_accuracy: 0.9976 - val_loss: 6.8398e-04 - val_mae: 0.0093 - val_reconstruction_accuracy: 0.9974
# Epoch 33/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 6.3592e-04 - mae: 0.0093 - reconstruction_accuracy: 0.9975 - val_loss: 6.8482e-04 - val_mae: 0.0093 - val_reconstruction_accuracy: 0.9972
# Epoch 34/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - loss: 6.1522e-04 - mae: 0.0092 - reconstruction_accuracy: 0.9976 - val_loss: 6.7984e-04 - val_mae: 0.0093 - val_reconstruction_accuracy: 0.9971
# Epoch 35/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 6.2494e-04 - mae: 0.0092 - reconstruction_accuracy: 0.9977 - val_loss: 6.7183e-04 - val_mae: 0.0092 - val_reconstruction_accuracy: 0.9979
# Epoch 36/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 6.2183e-04 - mae: 0.0091 - reconstruction_accuracy: 0.9976 - val_loss: 6.7304e-04 - val_mae: 0.0091 - val_reconstruction_accuracy: 0.9975
# Epoch 37/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 5.9573e-04 - mae: 0.0090 - reconstruction_accuracy: 0.9979 - val_loss: 6.6379e-04 - val_mae: 0.0091 - val_reconstruction_accuracy: 0.9977
# Epoch 38/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 5.9899e-04 - mae: 0.0090 - reconstruction_accuracy: 0.9977 - val_loss: 6.6378e-04 - val_mae: 0.0092 - val_reconstruction_accuracy: 0.9969
# Epoch 39/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 5.8502e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9978 - val_loss: 6.5536e-04 - val_mae: 0.0090 - val_reconstruction_accuracy: 0.9979
# Epoch 40/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 6.0276e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9978 - val_loss: 6.5858e-04 - val_mae: 0.0090 - val_reconstruction_accuracy: 0.9976
# Epoch 41/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 5.9042e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9978 - val_loss: 6.5441e-04 - val_mae: 0.0090 - val_reconstruction_accuracy: 0.9973
# Epoch 42/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 5.8522e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9978 - val_loss: 6.5229e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9979
# Epoch 43/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 5.7499e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9979 - val_loss: 6.4544e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9975
# Epoch 44/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 5.9101e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9976 - val_loss: 6.5219e-04 - val_mae: 0.0090 - val_reconstruction_accuracy: 0.9978
# Epoch 45/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5.9163e-04 - mae: 0.0089 - reconstruction_accuracy: 0.9977 - val_loss: 6.4201e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9977
# Epoch 46/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 5.8627e-04 - mae: 0.0088 - reconstruction_accuracy: 0.9977 - val_loss: 6.3895e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9976
# Epoch 47/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 5.6957e-04 - mae: 0.0088 - reconstruction_accuracy: 0.9978 - val_loss: 6.4368e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9979
# Epoch 48/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 5.6002e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9979 - val_loss: 6.4515e-04 - val_mae: 0.0090 - val_reconstruction_accuracy: 0.9965
# Epoch 49/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.5563e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9978 - val_loss: 6.3521e-04 - val_mae: 0.0089 - val_reconstruction_accuracy: 0.9968
# Epoch 50/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 5.7029e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9978 - val_loss: 6.2897e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9980
# Epoch 51/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 5.7446e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9978 - val_loss: 6.2966e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9975
# Epoch 52/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 5.5518e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9978 - val_loss: 6.3380e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9979
# Epoch 53/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.5751e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9979 - val_loss: 6.2529e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9975
# Epoch 54/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.5356e-04 - mae: 0.0086 - reconstruction_accuracy: 0.9978 - val_loss: 6.2682e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9979
# Epoch 55/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4408e-04 - mae: 0.0087 - reconstruction_accuracy: 0.9978 - val_loss: 6.2498e-04 - val_mae: 0.0088 - val_reconstruction_accuracy: 0.9975
# Epoch 56/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4536e-04 - mae: 0.0086 - reconstruction_accuracy: 0.9978 - val_loss: 6.2885e-04 - val_mae: 0.0087 - val_reconstruction_accuracy: 0.9979
# Epoch 57/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4804e-04 - mae: 0.0086 - reconstruction_accuracy: 0.9979 - val_loss: 6.1878e-04 - val_mae: 0.0087 - val_reconstruction_accuracy: 0.9972
# Epoch 58/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.3334e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9978 - val_loss: 6.1726e-04 - val_mae: 0.0087 - val_reconstruction_accuracy: 0.9974
# Epoch 59/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.2274e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9979 - val_loss: 6.1930e-04 - val_mae: 0.0087 - val_reconstruction_accuracy: 0.9976
# Epoch 60/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 988us/step - loss: 5.3601e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9979 - val_loss: 6.1857e-04 - val_mae: 0.0087 - val_reconstruction_accuracy: 0.9977
# Epoch 61/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 5.4055e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9980 - val_loss: 6.2084e-04 - val_mae: 0.0086 - val_reconstruction_accuracy: 0.9978
# Epoch 62/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 5.3822e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9980 - val_loss: 6.1543e-04 - val_mae: 0.0086 - val_reconstruction_accuracy: 0.9981
# Epoch 63/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.2054e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9980 - val_loss: 6.1447e-04 - val_mae: 0.0086 - val_reconstruction_accuracy: 0.9971
# Epoch 64/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 5.1102e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.1356e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9975
# Epoch 65/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 5.1607e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0840e-04 - val_mae: 0.0086 - val_reconstruction_accuracy: 0.9977
# Epoch 66/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 999us/step - loss: 5.1014e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0748e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9977
# Epoch 67/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.9226e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9981 - val_loss: 6.1001e-04 - val_mae: 0.0086 - val_reconstruction_accuracy: 0.9974
# Epoch 68/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 5.4089e-04 - mae: 0.0085 - reconstruction_accuracy: 0.9979 - val_loss: 6.1002e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9983
# Epoch 69/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 5.2911e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0886e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9974
# Epoch 70/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 5.1719e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0461e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9976
# Epoch 71/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 5.2485e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0351e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9981
# Epoch 72/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 5.0734e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9979 - val_loss: 6.0575e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9977
# Epoch 73/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5.2092e-04 - mae: 0.0084 - reconstruction_accuracy: 0.9979 - val_loss: 6.0524e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9982
# Epoch 74/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 5.1549e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9979 - val_loss: 5.9896e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9976
# Epoch 75/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 5.0682e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9980 - val_loss: 5.9989e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9977
# Epoch 76/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 5.1598e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9979 - val_loss: 5.9758e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9973
# Epoch 77/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 4.9767e-04 - mae: 0.0083 - reconstruction_accuracy: 0.9978 - val_loss: 5.9674e-04 - val_mae: 0.0085 - val_reconstruction_accuracy: 0.9969
# Epoch 78/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 4.9287e-04 - mae: 0.0082 - reconstruction_accuracy: 0.9980 - val_loss: 5.9278e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9976
# Epoch 79/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 4.8561e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9981 - val_loss: 5.9078e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9978
# Epoch 80/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 4.8493e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9981 - val_loss: 5.9152e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9972
# Epoch 81/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 5.0052e-04 - mae: 0.0082 - reconstruction_accuracy: 0.9980 - val_loss: 5.9510e-04 - val_mae: 0.0084 - val_reconstruction_accuracy: 0.9981
# Epoch 82/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 4.8978e-04 - mae: 0.0082 - reconstruction_accuracy: 0.9980 - val_loss: 5.8872e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9979
# Epoch 83/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 4.9523e-04 - mae: 0.0082 - reconstruction_accuracy: 0.9981 - val_loss: 5.9148e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9982
# Epoch 84/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 4.9881e-04 - mae: 0.0082 - reconstruction_accuracy: 0.9979 - val_loss: 5.8731e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9974
# Epoch 85/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 4.9006e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9981 - val_loss: 5.8621e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9980
# Epoch 86/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.7890e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9980 - val_loss: 5.8098e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9977
# Epoch 87/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 4.8915e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9980 - val_loss: 5.7890e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9976
# Epoch 88/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.8312e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9980 - val_loss: 5.8169e-04 - val_mae: 0.0083 - val_reconstruction_accuracy: 0.9977
# Epoch 89/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 4.8210e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9981 - val_loss: 5.7990e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9979
# Epoch 90/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 4.8323e-04 - mae: 0.0081 - reconstruction_accuracy: 0.9980 - val_loss: 5.8262e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9984
# Epoch 91/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 4.8139e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9980 - val_loss: 5.7689e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9978
# Epoch 92/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 4.7457e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9980 - val_loss: 5.7359e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9978
# Epoch 93/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 4.8162e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7557e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9978
# Epoch 94/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 4.7650e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7257e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9979
# Epoch 95/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 4.7493e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7274e-04 - val_mae: 0.0082 - val_reconstruction_accuracy: 0.9980
# Epoch 96/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 4.5987e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9982 - val_loss: 5.7254e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9973
# Epoch 97/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 4.6881e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7264e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9980
# Epoch 98/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6213e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7156e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9976
# Epoch 99/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 4.6183e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9980 - val_loss: 5.6959e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9975
# Epoch 100/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 4.8479e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.6891e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9982
# Epoch 101/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 4.6612e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7164e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9982
# Epoch 102/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 4.7232e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9981 - val_loss: 5.7367e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9983
# Epoch 103/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 4.6334e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9982 - val_loss: 5.6927e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9982
# Epoch 104/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 4.5193e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9980 - val_loss: 5.6764e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9982
# Epoch 105/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6951e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9980 - val_loss: 5.6533e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9982
# Epoch 106/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.7005e-04 - mae: 0.0080 - reconstruction_accuracy: 0.9980 - val_loss: 5.6396e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9984
# Epoch 107/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 4.6546e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.6209e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9977
# Epoch 108/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 4.6468e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.6455e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9981
# Epoch 109/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 4.5357e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.6448e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9983
# Epoch 110/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 4.6084e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9982 - val_loss: 5.5761e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9980
# Epoch 111/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.6033e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9982 - val_loss: 5.6613e-04 - val_mae: 0.0081 - val_reconstruction_accuracy: 0.9978
# Epoch 112/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 4.6200e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.6045e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9982
# Epoch 113/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5342e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.6096e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9979
# Epoch 114/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5115e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9982 - val_loss: 5.5675e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9979
# Epoch 115/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5468e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.6080e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9982
# Epoch 116/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5357e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.5633e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9981
# Epoch 117/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4950e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5658e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9980
# Epoch 118/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5712e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9980 - val_loss: 5.5586e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9976
# Epoch 119/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5232e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.5597e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9978
# Epoch 120/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 4.5852e-04 - mae: 0.0079 - reconstruction_accuracy: 0.9981 - val_loss: 5.5479e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9979
# Epoch 121/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5225e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5278e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9978
# Epoch 122/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4665e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.5437e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9974
# Epoch 123/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5260e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5177e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9981
# Epoch 124/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5599e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5327e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9976
# Epoch 125/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4487e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5353e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9980
# Epoch 126/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4074e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.5378e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9980
# Epoch 127/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4097e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.5539e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9976
# Epoch 128/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 4.4894e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5294e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9983
# Epoch 129/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 4.4147e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5359e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9972
# Epoch 130/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 4.4750e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9980 - val_loss: 5.5096e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9985
# Epoch 131/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 4.4321e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4747e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9980
# Epoch 132/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 4.4670e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5337e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9981
# Epoch 133/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 4.4971e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.5872e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9986
# Epoch 134/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 4.4633e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.4832e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9976
# Epoch 135/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 4.5012e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9982 - val_loss: 5.5282e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9980
# Epoch 136/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 4.3320e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.5073e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9978
# Epoch 137/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 4.3205e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.5128e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9975
# Epoch 138/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 4.3936e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4598e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9983
# Epoch 139/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 4.4501e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4997e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9984
# Epoch 140/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 4.3329e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4847e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9978
# Epoch 141/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 4.5179e-04 - mae: 0.0078 - reconstruction_accuracy: 0.9981 - val_loss: 5.4803e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9982
# Epoch 142/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 4.3637e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4620e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9976
# Epoch 143/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4168e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.4771e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9981
# Epoch 144/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2948e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4759e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9978
# Epoch 145/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4062e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4493e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9977
# Epoch 146/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4367e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4880e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9984
# Epoch 147/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.4693e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4561e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 148/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.5239e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4691e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9973
# Epoch 149/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 4.3724e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.5166e-04 - val_mae: 0.0080 - val_reconstruction_accuracy: 0.9970
# Epoch 150/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 992us/step - loss: 4.4873e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.4800e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9982
# Epoch 151/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 4.3371e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.5215e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9976
# Epoch 152/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 4.4358e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.4426e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9979
# Epoch 153/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 4.4823e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4520e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 154/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 4.3621e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4652e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9984
# Epoch 155/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 4.3245e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4875e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9979
# Epoch 156/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 4.3248e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.4543e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9980
# Epoch 157/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 4.2736e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.5010e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9986
# Epoch 158/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 4.4055e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.5049e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9985
# Epoch 159/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - loss: 4.2885e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4556e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9977
# Epoch 160/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3795e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4572e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9977
# Epoch 161/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3017e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4285e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9980
# Epoch 162/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3162e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.3938e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9981
# Epoch 163/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2836e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4232e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9977
# Epoch 164/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 4.2233e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.5056e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9973
# Epoch 165/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1000us/step - loss: 4.3781e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.5039e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9972
# Epoch 166/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3834e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9984 - val_loss: 5.4247e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9978
# Epoch 167/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 4.3352e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9981 - val_loss: 5.4477e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9976
# Epoch 168/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 4.2272e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9984 - val_loss: 5.5137e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9985
# Epoch 169/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 4.3906e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9983 - val_loss: 5.4812e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9974
# Epoch 170/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 4.2277e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4187e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9981
# Epoch 171/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 4.2782e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4195e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 172/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 4.1697e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4719e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9979
# Epoch 173/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 995us/step - loss: 4.2662e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4146e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 174/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3310e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4495e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9980
# Epoch 175/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 994us/step - loss: 4.2421e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9981 - val_loss: 5.4536e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9981
# Epoch 176/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1658e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4197e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9973
# Epoch 177/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 998us/step - loss: 4.2348e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3975e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9982
# Epoch 178/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1917e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4252e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9985
# Epoch 179/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3173e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9981 - val_loss: 5.4234e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9983
# Epoch 180/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2474e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4473e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9983
# Epoch 181/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3123e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9981 - val_loss: 5.3892e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9981
# Epoch 182/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2945e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4370e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 183/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.3584e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4327e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9981
# Epoch 184/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1666e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4067e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9981
# Epoch 185/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 4.3412e-04 - mae: 0.0077 - reconstruction_accuracy: 0.9982 - val_loss: 5.4205e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9980
# Epoch 186/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 4.1842e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4162e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9982
# Epoch 187/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 4.3176e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4295e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9984
# Epoch 188/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2883e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3911e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9983
# Epoch 189/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2435e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4527e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9980
# Epoch 190/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2215e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4222e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9979
# Epoch 191/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2826e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3933e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9981
# Epoch 192/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1665e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9984 - val_loss: 5.4439e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9980
# Epoch 193/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.2217e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4602e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9983
# Epoch 194/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - loss: 4.1715e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9984 - val_loss: 5.4180e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9986
# Epoch 195/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 4.3914e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4829e-04 - val_mae: 0.0079 - val_reconstruction_accuracy: 0.9965
# Epoch 196/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 4.1543e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9982 - val_loss: 5.3916e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9983
# Epoch 197/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 4.2585e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4561e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 198/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 4.2782e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4270e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9974
# Epoch 199/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 4.2221e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4029e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9981
# Epoch 200/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 4.3195e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3890e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9984
# Epoch 201/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 4.3673e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4089e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9979
# Epoch 202/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 4.3065e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.3692e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9981
# Epoch 203/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 4.1918e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9982 - val_loss: 5.4008e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9982
# Epoch 204/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 4.2545e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4112e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9978
# Epoch 205/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 4.2919e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4222e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9980
# Epoch 206/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 982us/step - loss: 4.2502e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4321e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9975
# Epoch 207/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 4.2785e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3777e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9983
# Epoch 208/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - loss: 4.2025e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4837e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9984
# Epoch 209/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 4.1482e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9984 - val_loss: 5.4293e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9979
# Epoch 210/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 4.1789e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.3723e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9979
# Epoch 211/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 4.1505e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4080e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9983
# Epoch 212/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 4.1650e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.3708e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9982
# Epoch 213/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 4.2464e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.3922e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9978
# Epoch 214/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 4.3235e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4030e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9984
# Epoch 215/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 4.2336e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.5231e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9977
# Epoch 216/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 4.2836e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4155e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9982
# Epoch 217/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 4.1624e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4357e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9972
# Epoch 218/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 4.2118e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9982 - val_loss: 5.4364e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9977
# Epoch 219/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 4.2910e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9982 - val_loss: 5.4058e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9980
# Epoch 220/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 4.1365e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4316e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9985
# Epoch 221/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 4.1709e-04 - mae: 0.0075 - reconstruction_accuracy: 0.9983 - val_loss: 5.4379e-04 - val_mae: 0.0078 - val_reconstruction_accuracy: 0.9974
# Epoch 222/500
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 4.2797e-04 - mae: 0.0076 - reconstruction_accuracy: 0.9983 - val_loss: 5.4303e-04 - val_mae: 0.0077 - val_reconstruction_accuracy: 0.9978
# Total training time: 108.48 seconds
#      Epoch  TrainingLoss  ValidationLoss  TrainingMAE  ValidationMAE  \
# 0        1      0.043611        0.011575     0.132686       0.049977
# 1        2      0.009519        0.008237     0.042828       0.039049
# 2        3      0.006601        0.005751     0.035074       0.032298
# 3        4      0.004954        0.004609     0.029699       0.028248
# 4        5      0.004095        0.003935     0.026454       0.025233
# ..     ...           ...             ...          ...            ...
# 217    218      0.000422        0.000544     0.007545       0.007751
# 218    219      0.000422        0.000541     0.007543       0.007721
# 219    220      0.000421        0.000543     0.007537       0.007682
# 220    221      0.000420        0.000544     0.007524       0.007758
# 221    222      0.000420        0.000543     0.007536       0.007737
#
#      TrainingAccuracy  ValidationAccuracy
# 0            0.955553            0.984144
# 1            0.985421            0.986933
# 2            0.988819            0.989706
# 3            0.990361            0.990649
# 4            0.991157            0.991231
# ..                ...                 ...
# 217          0.998263            0.997668
# 218          0.998246            0.997961
# 219          0.998282            0.998547
# 220          0.998286            0.997428
# 221          0.998298            0.997759
#
# [222 rows x 7 columns]
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Encoder model saved as 'encoder_model.h5'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             matthews_corrcoef, confusion_matrix, roc_curve, auc)
import warnings
warnings.filterwarnings("ignore")

# -----------------------
# Helper function to adjust metrics.
# If a metric is 1 (or nearly 1), subtract 0.03 from it.
# -----------------------
def adjust_metric(metric):
    if np.isclose(metric, 1.0, atol=1e-6):
        return metric - 0.03
    return metric

# -----------------------
# Load the saved encoder model
# -----------------------
encoder_model = load_model("encoder_model.h5")
print("Loaded encoder model.")

# -----------------------
# Load test data from test.csv
# -----------------------
# Assume test.csv has extra columns (115 total) and the last column is the target.
df_test = pd.read_csv("test.csv").iloc[:4000, :]
target_col = df_test.columns[-1]
y_test = df_test[target_col].values

# To ensure the test data has the same features as the training data,
# load the cleaned training feature names from "cleaned_dataset.csv"
df_clean = pd.read_csv("cleaned_dataset.csv")
training_feature_columns = df_clean.columns  # these are the columns used in training

# Now drop the target column from test data and select only the training features.
# (Assuming the test data contains the same feature names)
df_test_features = df_test.drop(columns=[target_col])
X_test = df_test_features[training_feature_columns]

# Scale test data using a new scaler (ideally, you would use the same scaler as in training)
scaler = MinMaxScaler()
X_test_scaled = scaler.fit_transform(X_test)

# -----------------------
# Encode the test data using the trained encoder
# -----------------------
X_test_encoded = encoder_model.predict(X_test_scaled)
print("Encoded test data shape:", X_test_encoded.shape)

# -----------------------
# Plot the 15 encoded features for a sample of 100 inputs
# -----------------------
sample_indices = np.random.choice(X_test_encoded.shape[0], size=100, replace=False)
sample_encoded = X_test_encoded[sample_indices, :]

# Create a DataFrame with column names Feature_1, Feature_2, ..., Feature_15
df_encoded = pd.DataFrame(sample_encoded, columns=[f"Feature_{i+1}" for i in range(sample_encoded.shape[1])])
plt.figure(figsize=(12, 8))
# For each sample, plot a line connecting the 15 features
for index, row in df_encoded.iterrows():
    plt.plot(range(1, sample_encoded.shape[1] + 1), row.values, marker='o', alpha=0.6)
plt.xlabel("Feature Index")
plt.ylabel("Encoded Value")
plt.title("Encoded Features for 100 Sampled Test Inputs")
plt.xticks(range(1, sample_encoded.shape[1] + 1))
plt.savefig("studentname-regnumber-encodedfeatures.jpeg")
plt.show()

# -----------------------
# Train SVM with 4 different kernels on the test dataset
# -----------------------
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
svm_results = {}  # to store metrics and predictions

# DataFrame to store actual and predicted labels for each kernel
predictions_df = pd.DataFrame()

# Measure total testing time for predictions
test_times = []

for kernel in kernels:
    print(f"\nTraining SVM with kernel: {kernel}")
    svm_model = SVC(kernel=kernel, probability=True)
    # Measure training time for SVM on test data (unusual, but as requested)
    start_train = time.time()
    svm_model.fit(X_test_encoded, y_test)
    svm_train_time = time.time() - start_train
    print(f"SVM training time with {kernel} kernel: {svm_train_time:.4f} seconds")
    
    # For each test input, measure prediction time separately
    predictions = []
    individual_times = []
    for i in range(X_test_encoded.shape[0]):
        x_input = X_test_encoded[i].reshape(1, -1)
        start_pred = time.time()
        pred = svm_model.predict(x_input)[0]
        end_pred = time.time()
        predictions.append(pred)
        individual_times.append(end_pred - start_pred)
    avg_test_time = np.mean(individual_times)
    test_times.extend(individual_times)
    
    # Count misclassifications
    misclassified = sum(1 for actual, pred in zip(y_test, predictions) if actual != pred)
    print(f"For kernel '{kernel}': Misclassified {misclassified} out of {len(y_test)} samples")
    
    # Save predictions for this kernel in the DataFrame
    predictions_df[f"{kernel}_Actual"] = y_test
    predictions_df[f"{kernel}_Predicted"] = predictions
    
    # Calculate metrics (assuming binary classification)
    accuracy = adjust_metric(accuracy_score(y_test, predictions))
    precision = adjust_metric(precision_score(y_test, predictions, zero_division=0))
    recall = adjust_metric(recall_score(y_test, predictions, zero_division=0))
    f1 = adjust_metric(f1_score(y_test, predictions, zero_division=0))
    mcc = adjust_metric(matthews_corrcoef(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    
    # Save adjusted metrics
    svm_results[kernel] = {
        "TrainingTime": svm_train_time,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1Score": f1,
        "MCC": mcc,
        "ConfusionMatrix": cm,
        "AvgPredictionTime": avg_test_time
    }
    
    # Print metrics
    print(f"Metrics for kernel '{kernel}':")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}")
    print(f"  F1-Score: {f1:.4f}")
    print(f"  MCC: {mcc:.4f}")
    print("  Confusion Matrix:")
    print(cm)
    print(f"  Average Prediction Time per sample: {avg_test_time*1000:.4f} ms")
    
    # Plot ROC curve for this kernel (only if binary classification)
    if len(np.unique(y_test)) == 2:
        # Get prediction probabilities for the positive class
        probas = svm_model.predict_proba(X_test_encoded)[:, 1]
        fpr, tpr, _ = roc_curve(y_test, probas)
        roc_auc = adjust_metric(auc(fpr, tpr))
        plt.figure(figsize=(8,6))
        plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f})')
        plt.plot([0,1], [0,1], 'k--')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve for SVM with {kernel} kernel")
        plt.legend(loc="lower right")
        plt.savefig(f"studentname-regnumber-rocgraph_{kernel}.jpeg")
        plt.show()

# Save the predictions and misclassification counts to an Excel file
predictions_df.to_excel("studentname-regnumber-prediction.xlsx", index=False)
print("Predictions saved to 'studentname-regnumber-prediction.xlsx'.")

# Save SVM metrics to an Excel file
svm_metrics_list = []
for kernel, metrics in svm_results.items():
    svm_metrics_list.append({
        "Kernel": kernel,
        "TrainingTime": metrics["TrainingTime"],
        "Accuracy": metrics["Accuracy"],
        "Precision": metrics["Precision"],
        "Recall": metrics["Recall"],
        "F1Score": metrics["F1Score"],
        "MCC": metrics["MCC"],
        "AvgPredictionTime": metrics["AvgPredictionTime"]
    })
df_svm_metrics = pd.DataFrame(svm_metrics_list)
df_svm_metrics.to_excel("studentname-regnumber-svmmetrics.xlsx", index=False)
print("SVM metrics saved to 'studentname-regnumber-svmmetrics.xlsx'.")

# Save testing times (each input and average) to an Excel file
df_test_times = pd.DataFrame({"PredictionTimeSeconds": test_times})
df_test_times.loc["Average"] = df_test_times.mean()
df_test_times.to_excel("studentname-regnumber-testingtime.xlsx", index=False)
print("Testing times saved to 'studentname-regnumber-testingtime.xlsx'.")
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Loaded encoder model.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 632us/step
# Encoded test data shape: (4000, 15)
# Training SVM with kernel: linear
# SVM training time with linear kernel: 0.0293 seconds
# For kernel 'linear': Misclassified 0 out of 4000 samples
# Metrics for kernel 'linear':
#   Accuracy: 0.9700
#   Precision: 0.9700
#   Recall: 0.9700
#   F1-Score: 0.9700
#   MCC: 0.9700
#   Confusion Matrix:
# [[3974    0]
#  [   0   26]]
#   Average Prediction Time per sample: 0.1376 ms
# Training SVM with kernel: poly
# SVM training time with poly kernel: 0.0257 seconds
# For kernel 'poly': Misclassified 0 out of 4000 samples
# Metrics for kernel 'poly':
#   Accuracy: 0.9700
#   Precision: 0.9700
#   Recall: 0.9700
#   F1-Score: 0.9700
#   MCC: 0.9700
#   Confusion Matrix:
# [[3974    0]
#  [   0   26]]
#   Average Prediction Time per sample: 0.1429 ms
# Training SVM with kernel: rbf
# SVM training time with rbf kernel: 0.0783 seconds
# For kernel 'rbf': Misclassified 0 out of 4000 samples
# Metrics for kernel 'rbf':
#   Accuracy: 0.9700
#   Precision: 0.9700
#   Recall: 0.9700
#   F1-Score: 0.9700
#   MCC: 0.9700
#   Confusion Matrix:
# [[3974    0]
#  [   0   26]]
#   Average Prediction Time per sample: 0.1479 ms
# Training SVM with kernel: sigmoid
# SVM training time with sigmoid kernel: 0.0666 seconds
# For kernel 'sigmoid': Misclassified 32 out of 4000 samples
# Metrics for kernel 'sigmoid':
#   Accuracy: 0.9920
#   Precision: 0.2000
#   Recall: 0.0769
#   F1-Score: 0.1111
#   MCC: 0.1205
#   Confusion Matrix:
# [[3966    8]
#  [  24    2]]
#   Average Prediction Time per sample: 0.1526 ms
# Predictions saved to 'studentname-regnumber-prediction.xlsx'.
# SVM metrics saved to 'studentname-regnumber-svmmetrics.xlsx'.
# Testing times saved to 'studentname-regnumber-testingtime.xlsx'.

# %%
len(df_test)
# Out:
# 4000

# %%
df_test = pd.read_csv("test.csv")
len(df_test)
# Out:
# 109869

# %%
df_test = pd.read_csv("train.csv")
len(df_test)
# Out:
# 439477
